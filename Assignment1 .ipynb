# %% [markdown]
# **ASSIGNMENT - 1 **

# %% [markdown]
# MUKKAWAR SRIYA,
# 21BPS1418

# %% [markdown]
# TASK 1 -> Create a pandas dataframe (DataFrame name as 'df') with numpy random vales ( 4 features 4 observations)

# %%
import pandas as pd
import numpy as np

data = np.random.rand(4,4)
df = pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.650139  0.387209  0.782988  0.805625
# 1  0.807181  0.870870  0.840636  0.075508
# 2  0.524483  0.262139  0.229893  0.915792
# 3  0.327975  0.821445  0.521771  0.726427

# %% [markdown]
# TASK 2 -> Rename the task-1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' &
#  'Random value 4'

# %%
df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.650139        0.387209        0.782988        0.805625
# 1        0.807181        0.870870        0.840636        0.075508
# 2        0.524483        0.262139        0.229893        0.915792
# 3        0.327975        0.821445        0.521771        0.726427

# %% [markdown]
# TASK 3 -> Find the descriptive statistics of the 'df' dataframe.

# %%
desc_stats = df.describe()
desc_stats
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.577445        0.585416        0.593822        0.630838
# std          0.202570        0.306043        0.279485        0.378276
# min          0.327975        0.262139        0.229893        0.075508
# 25%          0.475356        0.355942        0.448802        0.563698
# 50%          0.587311        0.604327        0.652380        0.766026
# 75%          0.689399        0.833802        0.797400        0.833167
# max          0.807181        0.870870        0.840636        0.915792

# %% [markdown]
# TASK 4 -> Check for the null values in 'df' and find the data type of the columns.

# %%
print(df.isnull().sum())
data_types = df.dtypes
print("\n")
print("Data types of the columns are: ")
print(data_types)
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64
#
#
# Data types of the columns are:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %% [markdown]
# TASK 5 ->  Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
df.iloc[:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.387209        0.782988
# 1        0.870870        0.840636
# 2        0.262139        0.229893
# 3        0.821445        0.521771

# %%
df.loc[:, 'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.387209        0.782988
# 1        0.870870        0.840636
# 2        0.262139        0.229893
# 3        0.821445        0.521771
